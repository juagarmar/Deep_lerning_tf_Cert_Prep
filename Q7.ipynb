# %% [markdown]
# <a href="https://colab.research.google.com/github/juagarmar/Deep_lerning_tf_Cert_Prep/blob/main/Q7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question

# %% [markdown]
# Build a model to classify images from the Multi-class Weather Dataset for Image Classification.
#
# Images should be normalized and resized to 224x224.
#
# Data augmentation may help you improve your results.
#
# Please save the model in the location given by **model_path**.

# %%
# !wget https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/TensorFlowDeveloperCertificate/submit_and_test_model_q7.py url -O /tmp/submit_and_test_model_q7.py

import sys
sys.path.append('/tmp/')
# Out:
# --2024-05-23 13:35:26--  https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/TensorFlowDeveloperCertificate/submit_and_test_model_q7.py
# Resolving utils-computervisiondeveloper.s3.amazonaws.com (utils-computervisiondeveloper.s3.amazonaws.com)... 52.216.49.161, 3.5.29.245, 16.182.100.97, ...
# Connecting to utils-computervisiondeveloper.s3.amazonaws.com (utils-computervisiondeveloper.s3.amazonaws.com)|52.216.49.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1137 (1.1K) [text/x-python]
# Saving to: ‘/tmp/submit_and_test_model_q7.py’
#
# /tmp/submit_and_tes 100%[===================>]   1.11K  --.-KB/s    in 0s
#
# 2024-05-23 13:35:26 (70.3 MB/s) - ‘/tmp/submit_and_test_model_q7.py’ saved [1137/1137]
#
# --2024-05-23 13:35:26--  http://url/
# Resolving url (url)... failed: Name or service not known.
# wget: unable to resolve host address ‘url’
# FINISHED --2024-05-23 13:35:26--
# Total wall clock time: 0.2s
# ...

# %%
model_path = '/tmp/model.h5'

# %%
# We will be using the Multi-class Weather Dataset for Image Classification
# You can find the dataset here: https://data.mendeley.com/datasets/4drtyfjtfy/1
# The dataset was arranged into three sets: train, val and test. Some images were removed.
# Ajayi, Gbeminiyi (2018), “Multi-class Weather Dataset for Image Classification”, Mendeley Data, V1, doi: 10.17632/4drtyfjtfy.1

# !wget https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/TensorFlowDeveloperCertificate/weather-data.zip

# !unzip /content/weather-data.zip -d /tmp/
# Out:
# --2024-05-23 13:35:34--  https://utils-computervisiondeveloper.s3.amazonaws.com/media/public/TensorFlowDeveloperCertificate/weather-data.zip
# Resolving utils-computervisiondeveloper.s3.amazonaws.com (utils-computervisiondeveloper.s3.amazonaws.com)... 54.231.198.113, 3.5.29.23, 52.216.144.187, ...
# Connecting to utils-computervisiondeveloper.s3.amazonaws.com (utils-computervisiondeveloper.s3.amazonaws.com)|54.231.198.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93559077 (89M) [application/zip]
# Saving to: ‘weather-data.zip’
#
# weather-data.zip    100%[===================>]  89.22M  56.1MB/s    in 1.6s
#
# 2024-05-23 13:35:36 (56.1 MB/s) - ‘weather-data.zip’ saved [93559077/93559077]
#
# Archive:  /content/weather-data.zip
#    creating: /tmp/weather-data/
#    creating: /tmp/weather-data/test/
#    creating: /tmp/weather-data/test/cloudy/
#   inflating: /tmp/weather-data/test/cloudy/cloudy272.jpg
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1.0/255
)

target_size=(224, 224)
class_mode='categorical'
batch_size=32

train_data_generator = datagen.flow_from_directory(
    '/tmp/weather-data/train',
    target_size= target_size,
    batch_size= batch_size,
    class_mode= 'categorical'
)

validation_data_generator = datagen.flow_from_directory(
    '/tmp/weather-data/test',
    target_size= target_size,
    batch_size= batch_size,
    class_mode= 'categorical'
)
# Out:
# Found 903 images belonging to 4 classes.
# Found 66 images belonging to 4 classes.

# %%
from tensorflow.keras import Sequential

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Assuming BloodMNIST has 8 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(
    train_data_generator,
    epochs=10,
    validation_data=validation_data_generator
)

model.save(model_path)
# Out:
# Epoch 1/10
# 29/29 [==============================] - 10s 147ms/step - loss: 2.8140 - accuracy: 0.5792 - val_loss: 0.3567 - val_accuracy: 0.9091
# Epoch 2/10
# 29/29 [==============================] - 5s 169ms/step - loss: 0.5038 - accuracy: 0.8140 - val_loss: 0.4439 - val_accuracy: 0.8788
# Epoch 3/10
# 29/29 [==============================] - 5s 154ms/step - loss: 0.2784 - accuracy: 0.9003 - val_loss: 0.3294 - val_accuracy: 0.9242
# Epoch 4/10
# 29/29 [==============================] - 5s 155ms/step - loss: 0.2210 - accuracy: 0.9181 - val_loss: 0.3303 - val_accuracy: 0.9242
# Epoch 5/10
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1592 - accuracy: 0.9480 - val_loss: 0.3129 - val_accuracy: 0.9242
# Epoch 6/10
# 29/29 [==============================] - 5s 159ms/step - loss: 0.1341 - accuracy: 0.9535 - val_loss: 0.2400 - val_accuracy: 0.9545
# Epoch 7/10
# ...

# %%
from submit_and_test_model_q7 import submit_and_test_model


submit_and_test_model(model_path)
# Out:
# Found 66 images belonging to 4 classes.
# 5/5

# %% [markdown]
# ## DISCLAIMER:
#
# This set of exercises and practice materials is provided solely for educational and practice purposes. It is not an official resource for the TensorFlow Developer Certificate Exam or endorsed by any official certifying authority. The content in these notebooks is created independently and may not accurately reflect the content, format, or difficulty level of the actual exam.
#
# While we have made efforts to ensure the quality and correctness of the exercises, we cannot guarantee that this resource will adequately prepare you for the exam. It is advisable to consult official exam materials, study guides, and resources provided by the certifying authority to ensure you are adequately prepared.
#
# Use this resource at your own discretion and consider it as supplementary to your exam preparation efforts. Success on the exam depends on a thorough understanding of the official exam objectives and materials.
